# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("results.csv", encoding = 'unicode_escape')
df.columns
# Out:
# Index(['Season', 'DateTime', 'HomeTeam', 'AwayTeam', 'FTHG', 'FTAG', 'FTR',
#        'HTHG', 'HTAG', 'HTR', 'Referee', 'HS', 'AS', 'HST', 'AST', 'HC', 'AC',
#        'HF', 'AF', 'HY', 'AY', 'HR', 'AR'],
#       dtype='object')

# %%
df = df[df["Season"] == "2019-20"]

# %%
def winner(row):
    if row["FTR"] == "H":
        return row["HomeTeam"]
    elif row["FTR"] == "A":
        return row["AwayTeam"]
    else:
        return "Draw"

df['Winner'] = df.apply(winner, axis=1)

def points(row):
    if row["FTR"] == "H":
        return 3
    elif row["FTR"] == "A":
        return 0
    else:
        return 1

df['Points'] = df.apply(points, axis=1)

def pointsaway(row):
    if row["FTR"] == "H":
        return 0
    elif row["FTR"] == "A":
        return 3
    else:
        return 1
    
    
df['PointsAway'] = df.apply(pointsaway, axis=1)
#htlist = list(df["HomeTeam"])
#atlist = list(df["AwayTeam"])
#ftrlist = list(df["FTR"])

#winners = list(map(lambda x,y,z: winner(x,y,z),htlist,atlist,ftrlist))




#df["Winner"]

#df["Winner"].apply(lambda x: winner(ht = df["HomeTeam"], at = df["AwayTeam"], ftr = df["FTR"]))
    
#df["Winner"].map((lambda x,y,z = winner(x,y,z),df.HomeTeam,df.AwayTeam,df.FTR))

# %%
df
# Out:
#         Season              DateTime        HomeTeam          AwayTeam  FTHG  \
# 10044  2019-20  2019-08-09T20:00:00Z       Liverpool           Norwich     4
# 10045  2019-20  2019-08-10T12:30:00Z        West Ham          Man City     0
# 10046  2019-20  2019-08-10T15:00:00Z     Bournemouth  Sheffield United     1
# 10047  2019-20  2019-08-10T15:00:00Z         Burnley       Southampton     3
# 10048  2019-20  2019-08-10T15:00:00Z  Crystal Palace           Everton     0
# ...        ...                   ...             ...               ...   ...
# 10419  2019-20  2020-07-26T16:00:00Z       Leicester        Man United     0
# 10420  2019-20  2020-07-26T16:00:00Z        Man City           Norwich     5
# 10421  2019-20  2020-07-26T16:00:00Z       Newcastle         Liverpool     1
# 10422  2019-20  2020-07-26T16:00:00Z     Southampton  Sheffield United     3
# 10423  2019-20  2020-07-26T16:00:00Z        West Ham       Aston Villa     1
#
#        FTAG FTR  HTHG  HTAG HTR  ...   AC    HF    AF   HY   AY   HR   AR  \
# 10044     1   H   4.0   0.0   H  ...  2.0   9.0   9.0  0.0  2.0  0.0  0.0
# 10045     5   A   0.0   1.0   A  ...  1.0   6.0  13.0  2.0  2.0  0.0  0.0
# 10046     1   D   0.0   0.0   D  ...  4.0  10.0  19.0  2.0  1.0  0.0  0.0
# 10047     0   H   0.0   0.0   D  ...  7.0   6.0  12.0  0.0  0.0  0.0  0.0
# 10048     0   D   0.0   0.0   D  ...  2.0  16.0  14.0  2.0  1.0  0.0  1.0
# ...     ...  ..   ...   ...  ..  ...  ...   ...   ...  ...  ...  ...  ...
# 10419     2   A   0.0   0.0   D  ...  3.0  12.0  11.0  1.0  4.0  1.0  0.0
# 10420     0   H   2.0   0.0   H  ...  0.0   7.0   4.0  1.0  1.0  0.0  0.0
# 10421     3   A   1.0   1.0   D  ...  4.0  11.0   5.0  1.0  0.0  0.0  0.0
# 10422     1   H   0.0   1.0   A  ...  1.0   9.0  16.0  0.0  1.0  0.0  0.0
# 10423     1   D   0.0   0.0   D  ...  7.0  16.0  13.0  2.0  1.0  0.0  0.0
#
#             Winner  Points  PointsAway
# 10044    Liverpool       3           0
# 10045     Man City       0           3
# 10046         Draw       1           1
# 10047      Burnley       3           0
# 10048         Draw       1           1
# ...            ...     ...         ...
# 10419   Man United       0           3
# 10420     Man City       3           0
# 10421    Liverpool       0           3
# 10422  Southampton       3           0
# 10423         Draw       1           1
#
# [380 rows x 26 columns]

# %%
p_home = df.groupby('HomeTeam').sum()['Points'].sort_values(ascending=False)

# %%
p_away = df.groupby('AwayTeam').sum()['PointsAway'].sort_values(ascending=False)

# %%
g_home = df.groupby('HomeTeam').sum()['FTHG'].sort_values(ascending=False)

# %%
g_away = df.groupby('AwayTeam').sum()['FTAG'].sort_values(ascending=False)

# %%
g_away
# Out:
# AwayTeam
# Man City            45
# Chelsea             39
# Liverpool           33
# Leicester           32
# Southampton         30
# Man United          26
# Tottenham           25
# Wolves              24
# Everton             20
# Arsenal             20
# Aston Villa         19
# Burnley             19
# Brighton            19
# West Ham            19
# Newcastle           18
# Bournemouth         18
# Crystal Palace      16
# Sheffield United    15
# Watford             14
# Norwich              7
# Name: FTAG, dtype: int64

# %%
table = p_home + p_away

# %%
table = pd.DataFrame(table.sort_values(ascending = False))

# %%
table["HG"] = g_home
table["AG"] = g_away
table["Diff"] = (g_home - g_away) / (g_home + g_away)
table.sort_values(by="Diff", ascending=False)
# Out:
#                   Points  Market value  HG  AG      Diff
# Team
# Norwich               21         0.110  19   7  0.461538
# Arsenal               56         0.680  36  20  0.285714
# Sheffield United      54         0.110  24  15  0.230769
# West Ham              39         0.371  30  19  0.224490
# Liverpool             99         1.090  52  33  0.223529
# Watford               34         0.270  22  14  0.222222
# Man United            66         0.775  40  26  0.212121
# Tottenham             59         1.040  36  25  0.180328
# Man City              81         1.270  57  45  0.117647
# Burnley               54         0.205  24  19  0.116279
# Bournemouth           34         0.311  22  18  0.100000
# Everton               49         0.525  24  20  0.090909
# Aston Villa           35         0.184  22  19  0.073171
# Wolves                59         0.315  27  24  0.058824
# Newcastle             44         0.312  20  18  0.052632
# Leicester             62         0.384  35  32  0.044776
# Brighton              41         0.225  20  19  0.025641
# Crystal Palace        43         0.248  15  16 -0.032258
# Chelsea               66         0.797  30  39 -0.130435
# Southampton           52         0.259  21  30 -0.176471

# %%
table.columns = ["Points"]
table.index.name = "Team"

marktwert = [1.09, 1.27, 0.775, 0.797, 0.384, 1.04, 0.315, 0.680, 0.205, 0.110, 0.259, 0.525, 0.312, 0.248, 0.225, 0.371, 0.184, 0.311, 0.270, 0.110]

# %%
table
# Out:
#                   Points
# Team
# Liverpool             99
# Man City              81
# Man United            66
# Chelsea               66
# Leicester             62
# Tottenham             59
# Wolves                59
# Arsenal               56
# Burnley               54
# Sheffield United      54
# Southampton           52
# Everton               49
# Newcastle             44
# Crystal Palace        43
# Brighton              41
# West Ham              39
# Aston Villa           35
# Bournemouth           34
# Watford               34
# Norwich               21

# %%
table["Market value"] = marktwert

# %%
table
# Out:
#                   Points  Market value
# Team
# Liverpool             99         1.090
# Man City              81         1.270
# Man United            66         0.775
# Chelsea               66         0.797
# Leicester             62         0.384
# Tottenham             59         1.040
# Wolves                59         0.315
# Arsenal               56         0.680
# Burnley               54         0.205
# Sheffield United      54         0.110
# Southampton           52         0.259
# Everton               49         0.525
# Newcastle             44         0.312
# Crystal Palace        43         0.248
# Brighton              41         0.225
# West Ham              39         0.371
# Aston Villa           35         0.184
# Bournemouth           34         0.311
# Watford               34         0.270
# Norwich               21         0.110

# %%
np_mk = table["Market value"].to_numpy().reshape((-1, 1))
np_points = table["Points"].to_numpy()

# %%
model = LinearRegression().fit(np_mk, np_points)
regr = model.predict(np_mk)

# %%
plt.figure(figsize=(12,10))
plt.scatter(np_mk, np_points,  color='black')
plt.plot(np_mk,regr, color="blue")

for i, team in enumerate(table.index):
    x = np_mk[i]
    y = np_points[i]
    plt.scatter(x,y)
    plt.text(x+0.05,y,team,fontsize=10)

# %%
plt.show()

# %%
print('slope:', model.coef_)
# Out:
# slope: [40.28389201]
