# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
# Out:
#                                FTHG      FTAG      DIFF
# DateTime
# 1993-12-31 00:00:00+00:00  1.357724  1.134146  0.223577
# 1994-12-31 00:00:00+00:00  1.535088  1.153509  0.381579
# 1995-12-31 00:00:00+00:00  1.507042  1.028169  0.478873
# 1996-12-31 00:00:00+00:00  1.504000  1.104000  0.400000
# 1997-12-31 00:00:00+00:00  1.511568  1.092545  0.419023
# 1998-12-31 00:00:00+00:00  1.497312  1.069892  0.427419
# 1999-12-31 00:00:00+00:00  1.578667  1.104000  0.474667
# 2000-12-31 00:00:00+00:00  1.646154  1.087179  0.558974
# 2001-12-31 00:00:00+00:00  1.420912  1.155496  0.265416
# 2002-12-31 00:00:00+00:00  1.478261  1.076726  0.401535
# 2003-12-31 00:00:00+00:00  1.501393  1.189415  0.311978
# 2004-12-31 00:00:00+00:00  1.510204  1.160714  0.349490
# 2005-12-31 00:00:00+00:00  1.454545  1.026738  0.427807
# 2006-12-31 00:00:00+00:00  1.477157  0.956853  0.520305
# 2007-12-31 00:00:00+00:00  1.552561  1.123989  0.428571
# 2008-12-31 00:00:00+00:00  1.411609  1.134565  0.277045
# ...

# %%
df = pd.read_csv("results.csv", encoding = 'unicode_escape', usecols=["DateTime", "FTHG", "FTAG"], parse_dates=['DateTime'])

# %%
df["DIFF"] = df.FTHG - df.FTAG

# %%
type(df["DateTime"][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df = df.resample('Y', on='DateTime').mean()
#plt.plot_date(df["DateTime"], df["DIFF"])

# %%
plt.plot(df["DIFF"])

# %%
# Out:
#                                FTHG      FTAG      DIFF
# DateTime
# 1993-12-31 00:00:00+00:00  1.357724  1.134146  0.223577
# 1994-12-31 00:00:00+00:00  1.535088  1.153509  0.381579
# 1995-12-31 00:00:00+00:00  1.507042  1.028169  0.478873
# 1996-12-31 00:00:00+00:00  1.504000  1.104000  0.400000
# 1997-12-31 00:00:00+00:00  1.511568  1.092545  0.419023
# 1998-12-31 00:00:00+00:00  1.497312  1.069892  0.427419
# 1999-12-31 00:00:00+00:00  1.578667  1.104000  0.474667
# 2000-12-31 00:00:00+00:00  1.646154  1.087179  0.558974
# 2001-12-31 00:00:00+00:00  1.420912  1.155496  0.265416
# 2002-12-31 00:00:00+00:00  1.478261  1.076726  0.401535
# 2003-12-31 00:00:00+00:00  1.501393  1.189415  0.311978
# 2004-12-31 00:00:00+00:00  1.510204  1.160714  0.349490
# 2005-12-31 00:00:00+00:00  1.454545  1.026738  0.427807
# 2006-12-31 00:00:00+00:00  1.477157  0.956853  0.520305
# 2007-12-31 00:00:00+00:00  1.552561  1.123989  0.428571
# 2008-12-31 00:00:00+00:00  1.411609  1.134565  0.277045
# ...
