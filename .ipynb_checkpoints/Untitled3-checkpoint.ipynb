# %%
import pandas as pd

# %%
df = pd.read_csv("results.csv", encoding = 'unicode_escape', usecols=[0,1,2,3,4,5,6])

# %%
df = df[df["Season"] == "2019-20"]

# %%
def winner(row):
    if row["FTR"] == "H":
        return row["HomeTeam"]
    elif row["FTR"] == "A":
        return row["AwayTeam"]
    else:
        return "Draw"

df['Winner'] = df.apply(winner, axis=1)

def points(row):
    if row["FTR"] == "H":
        return 3
    elif row["FTR"] == "A":
        return 0
    else:
        return 1

df['Points'] = df.apply(points, axis=1)

def pointsaway(row):
    if row["FTR"] == "H":
        return 0
    elif row["FTR"] == "A":
        return 3
    else:
        return 1
    
    
df['PointsAway'] = df.apply(pointsaway, axis=1)
#htlist = list(df["HomeTeam"])
#atlist = list(df["AwayTeam"])
#ftrlist = list(df["FTR"])

#winners = list(map(lambda x,y,z: winner(x,y,z),htlist,atlist,ftrlist))




#df["Winner"]

#df["Winner"].apply(lambda x: winner(ht = df["HomeTeam"], at = df["AwayTeam"], ftr = df["FTR"]))
    
#df["Winner"].map((lambda x,y,z = winner(x,y,z),df.HomeTeam,df.AwayTeam,df.FTR))
# Out:
# <ipython-input-21-e51c36535618>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Winner'] = df.apply(winner, axis=1)
# <ipython-input-21-e51c36535618>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Points'] = df.apply(points, axis=1)
# <ipython-input-21-e51c36535618>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PointsAway'] = df.apply(pointsaway, axis=1)

# %%
df
# Out:
#         Season              DateTime        HomeTeam          AwayTeam  FTHG  \
# 10044  2019-20  2019-08-09T20:00:00Z       Liverpool           Norwich     4
# 10045  2019-20  2019-08-10T12:30:00Z        West Ham          Man City     0
# 10046  2019-20  2019-08-10T15:00:00Z     Bournemouth  Sheffield United     1
# 10047  2019-20  2019-08-10T15:00:00Z         Burnley       Southampton     3
# 10048  2019-20  2019-08-10T15:00:00Z  Crystal Palace           Everton     0
# ...        ...                   ...             ...               ...   ...
# 10419  2019-20  2020-07-26T16:00:00Z       Leicester        Man United     0
# 10420  2019-20  2020-07-26T16:00:00Z        Man City           Norwich     5
# 10421  2019-20  2020-07-26T16:00:00Z       Newcastle         Liverpool     1
# 10422  2019-20  2020-07-26T16:00:00Z     Southampton  Sheffield United     3
# 10423  2019-20  2020-07-26T16:00:00Z        West Ham       Aston Villa     1
#
#        FTAG FTR       Winner  Points  PointsAway
# 10044     1   H    Liverpool       3           0
# 10045     5   A     Man City       0           3
# 10046     1   D         Draw       1           1
# 10047     0   H      Burnley       3           0
# 10048     0   D         Draw       1           1
# ...     ...  ..          ...     ...         ...
# 10419     2   A   Man United       0           3
# 10420     0   H     Man City       3           0
# 10421     3   A    Liverpool       0           3
# 10422     1   H  Southampton       3           0
# 10423     1   D         Draw       1           1
#
# [380 rows x 10 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-1527f51cf682> in <module>
# ----> 1 df['Rank'] = df.groupby(['points'])
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6712         axis = self._get_axis_number(axis)
#    6713
# -> 6714         return DataFrameGroupBy(
#    6715             obj=self,
#    6716             keys=by,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     558             from pandas.core.groupby.grouper import get_grouper
#     559
# --> 560             grouper, exclusions, obj = get_grouper(
#     561                 obj,
#     562                 keys,
#
# ~/.local/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     814                 in_axis, name, level, gpr = False, None, gpr, None
#     815             else:
# --> 816                 raise KeyError(gpr)
#     817         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     818             # Add key to exclusions
#
# KeyError: 'points'
